# %% [markdown]
# # Day 1 Exercises
# ## Data Types

# %% [markdown]
# #### 1. What types are involved in the following expressions? What data type will each expression evaluate to?

# %%
8 * 2.5
# Out:
# 20.0

# %% [markdown]
# The operant "*" signifies multiplication so this line of code multiples 8 by 2.5 which is 20

# %%
9 / 2
# Out:
# 4.5

# %% [markdown]
# The operator "/" signifies division so 9/2 should return 4.5

# %%
1.5 * 2 >= 7 - 3
# Out:
# False

# %% [markdown]
# multiplication, greater than or equal to and subtraction. It should run in the order multiplication, subtraction and then greater than or equal to. 3 >= 4 and it should return "false"

# %% [markdown]
# #### 2. In which order will the expressions be evaluated?

# %%
6 * 3 + 7 * 4
# Out:
# 46

# %% [markdown]
# 1) 6 x 3 = 18
# 2) 7 x 4 = 28
# 3) 18 + 28 = 46

# %%
5 - 2 * 3 ** 4
# Out:
# -157

# %% [markdown]
# 1) 3 ^ 4 = 81
# 2) 81 x 2 = 162
# 3) 5 - 162 = -157

# %%
(5 - 2) * 3 ** 4
# Out:
# 243

# %% [markdown]
# 1) (5-2) = 3
# 2) 3 ^ 4 = 81
# 3) 81 x 3 = 243

# %%
5 + 2 >= 3 * 4
# Out:
# False

# %% [markdown]
# 1) 3 x 4 = 12
# 2) 5 + 2 = 7
# 3) 7 >= 12?
# Final result should give us "False"

# %% [markdown]
# ## Comments and Errors

# %% [markdown]
# #### 1. Which of these expressions results in an error? Why does each error occur?

# %%
((((5 * 4 ** 7))))
# Out:
# 81920

# %% [markdown]
# There wouldn't be an error, the extra parentheses are likely ignored and the mathematics rules apply inside

# %%
84 *= 0.5 / 7
# Out:
#   File "/tmp/ipykernel_15482/868797654.py", line 1
#     84 *= 0.5 / 7
#     ^
# SyntaxError: 'literal' is an illegal expression for augmented assignment

# %% [markdown]
# The "*=" is not a recognized operator so this should restult in an error because Python doesn't recognize it

# %%
(-(-(-(-5 * (4 + 3)))))
# Out:
# 35

# %% [markdown]
# Should not result in an error, it would just deal with the inner-most parentheses first and work its way outward

# %%
5 * 3 = weight
# Out:
#   File "/tmp/ipykernel_15482/3700621706.py", line 1
#     5 * 3 = weight
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# This should result in an error because a line of coding cannot begin with an integer

# %%
73 / -----------5
# Out:
# -14.6

# %% [markdown]
# I don't anticipate an error: it should deal with the negations before doing the division

# %% [markdown]
# #### 2. Write a block of code to check if the value is a string. If it is, print out a message saying it is valid. Otherwise, raise an exception with a message saying the value must be a string.

# %%
value = 6

# Your code goes here
if type(value) == str:
    print("Valid")
else:
    print("Value must be a string")
# Out:
# Value must be a string

# %% [markdown]
# #### 3. What are the following errors?

# %%
arr = [1, 2, 3]
print(arr[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_15482/2963248189.py in <cell line: 0>()
#       1 arr = [1, 2, 3]
# ----> 2 print(arr[3])
#
# IndexError: list index out of range

# %% [markdown]
#  The list is not long enough to fetch [3]

# %%
fullName = "Taylor Swift"
print(full_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_15482/3996353418.py in <cell line: 0>()
#       1 fullName = "Taylor Swift"
# ----> 2 print(full_name)
#
# NameError: name 'full_name' is not defined

# %% [markdown]
#  'fullName' definition and  'full_name' return don't match

# %%
2 + '2' + 4

# %% [markdown]
# You can't add an integer to a string and use an operator. Operators function differently when dealing with all strings or all integers but they can't be mixed.

# %% [markdown]
# #### 1. Following the function design recipe, define a function that converts kilometers into miles. (Assume there are 1.6 kilometers in a mile.)

# %%
# Your code goes here
def convert_to_miles(kilometers):
    miles = kilometers / 1.6
    return miles
    convert_to_miles(5)

# %%
convert_to_miles(5)
# Out:
# 3.125

# %% [markdown]
# #### 2. What value is printed in the below code?

# %%
answer = 3

def answer_to_everything():
    '''Return the answer to life, the universe, and everything'''
    answer = 42
    return answer

answer_to_everything()

print(answer)
# it should be 3 as we defined it in the first line which was the global variable
# the local variable inside is over-ridden by the global
# Out:
# 3

# %% [markdown]
# #### 3. Complete the body of the function. You can assume num is always >= 0.

# %%
def repeat(string, num):
    ''' Return string repeated num times.
    >>> repeat('yes', 4)
    'yesyesyesyes'
    >>> repeat('no', 0)
    # your expected output
     >>> repeat('yesnomaybe', 3)
    # your expected output here
    '''

    return (string * num)

# %%
repeat("hi", 3)
# Out:
# 'hihihi'

# %%
repeat("yes", 4)
# Out:
# 'yesyesyesyes'

# %%
repeat("no", 0)
# Out:
# ''

# %%
repeat("yesnomaybe", 3)
# Out:
# 'yesnomaybeyesnomaybeyesnomaybe'

# %% [markdown]
# I tested the code as it was given but it didn't run for me so I tweaked it and ran the repeat requests to see if it would work!

# %% [markdown]
# #### 4. Complete the function below. You can assume that number will always be a string with 10 digits and that the first 3 digits will always be the area code.

# %%
def is_416_number(number):
    ''' Check whether the number has a 416 area code.
    >>> is_416_number('(416)-555-5555')
    True
    >>> is_416_number('514 416 5555')
    False
    >>> is_416_number('4165554160')
    True
    '''
    # Your code goes here
    if number[0:3] == "416":
        return True
    elif number[1:4] == "416":
        return True
    else:
        return False
    # Hint: replace () and spaces with nothing

# %%
is_416_number('(416)-555-5555')
# Out:
# True

# %%
is_416_number('514 416 5555')
# Out:
# False

# %%
is_416_number('4165554160')
# Out:
# True

# %% [markdown]
# yay!
